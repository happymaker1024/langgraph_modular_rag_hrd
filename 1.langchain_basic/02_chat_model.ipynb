# %% [markdown]
# # 02. Chat Model 호출
#
# LangChain에서 OpenAI ChatModel을 불러오고 기본 호출 방법을 실습합니다.

# %% [markdown]
# ## 1. 환경 설정

# %%
from dotenv import load_dotenv
load_dotenv(override=True, dotenv_path="../.env")
# Out:
# True

# %% [markdown]
# ## 2. ChatOpenAI 초기화
#
# - `model`: 사용할 모델 이름
# - `temperature`: 0에 가까울수록 일관된 답변, 1에 가까울수록 창의적인 답변

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.2)
print(llm)
# Out:
# output_version=None profile={'name': 'GPT-4o mini', 'release_date': '2024-07-18', 'last_updated': '2024-07-18', 'open_weights': False, 'max_input_tokens': 128000, 'max_output_tokens': 16384, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x0000024C8D787E90> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000024C8BEE91F0> root_client=<openai.OpenAI object at 0x0000024C89324380> root_async_client=<openai.AsyncOpenAI object at 0x0000024C8B8B5AC0> model_name='gpt-4o-mini' temperature=0.2 model_kwargs={} openai_api_key=SecretStr('**********') openai_proxy=None stream_usage=True stream_chunk_timeout=120.0

# %% [markdown]
# ## 3. 기본 호출 - invoke()
#
# 문자열을 직접 전달하면 HumanMessage로 자동 변환됩니다.

# %%
question = "modular RAG에 대해 알여줘"
response = llm.invoke(question)
# Out:
# Modular RAG(Recall-Augmented Generation)는 정보 검색과 자연어 생성(NLG) 기술을 결합한 모델입니다. 이 접근 방식은 주로 질문 응답 시스템이나 대화형 AI에서 사용되며, 다음과 같은 주요 구성 요소로 이루어져 있습니다.
#
# 1. **모듈화**: Modular RAG는 여러 개의 모듈로 구성되어 있어 각 모듈이 특정 작업을 수행합니다. 예를 들어, 정보 검색 모듈과 생성 모듈이 분리되어 있어, 검색 모듈이 관련 정보를 찾아내고, 생성 모듈이 그 정보를 바탕으로 자연어 응답을 생성합니다.
#
# 2. **정보 검색**: 이 단계에서는 주어진 질문이나 입력에 대해 관련된 정보를 데이터베이스나 문서 집합에서 검색합니다. 이 과정은 일반적으로 BM25와 같은 전통적인 정보 검색 기법이나, BERT와 같은 최신 딥러닝 모델을 활용하여 수행됩니다.
#
# 3. **응답 생성**: 검색된 정보를 바탕으로 자연어로 응답을 생성하는 단계입니다. 이 과정에서는 GPT와 같은 대형 언어 모델이 사용될 수 있으며, 검색된 정보를 효과적으로 통합하여 자연스럽고 일관된 응답을 만들어냅니다.
#
# 4. **피드백 루프**: Modular RAG는 사용자 피드백을 통해 지속적으로 개선될 수 있습니다. 사용자가 제공하는 피드백을 통해 모델의 성능을 향상시키고, 더 나은 검색 및 생성 결과를 도출할 수 있습니다.
#
# 이러한 구조 덕분에 Modular RAG는 정보의 정확성과 자연어 생성의 품질을 동시에 개선할 수 있는 장점을 가지고 있습니다. 특히, 대량의 데이터에서 유용한 정보를 추출하고 이를 바탕으로 유의미한 응답을 생성하는 데 효과적입니다.

# %%
print(response.content)
# Out:
# Modular RAG(Recall-Augmented Generation)는 정보 검색과 자연어 생성(NLG) 기술을 결합한 모델입니다. 이 접근 방식은 주로 질문 응답 시스템이나 대화형 AI에서 사용되며, 다음과 같은 주요 구성 요소로 이루어져 있습니다.
#
# 1. **모듈화**: Modular RAG는 여러 개의 모듈로 구성되어 있어 각 모듈이 특정 작업을 수행합니다. 예를 들어, 정보 검색 모듈과 생성 모듈이 분리되어 있어, 검색 모듈이 관련 정보를 찾아내고, 생성 모듈이 그 정보를 바탕으로 자연어 응답을 생성합니다.
#
# 2. **정보 검색**: 이 단계에서는 주어진 질문이나 입력에 대해 관련된 정보를 데이터베이스나 문서 집합에서 검색합니다. 이 과정은 일반적으로 BM25와 같은 전통적인 정보 검색 기법이나, BERT와 같은 최신 딥러닝 모델을 활용하여 수행됩니다.
#
# 3. **응답 생성**: 검색된 정보를 바탕으로 자연어로 응답을 생성하는 단계입니다. 이 과정에서는 GPT와 같은 대형 언어 모델이 사용될 수 있으며, 검색된 정보를 효과적으로 통합하여 자연스럽고 일관된 응답을 만들어냅니다.
#
# 4. **피드백 루프**: Modular RAG는 사용자 피드백을 통해 지속적으로 개선될 수 있습니다. 사용자가 제공하는 피드백을 통해 모델의 성능을 향상시키고, 더 나은 검색 및 생성 결과를 도출할 수 있습니다.
#
# 이러한 구조 덕분에 Modular RAG는 정보의 정확성과 자연어 생성의 품질을 동시에 개선할 수 있는 장점을 가지고 있습니다. 특히, 대량의 데이터에서 유용한 정보를 추출하고 이를 바탕으로 유의미한 응답을 생성하는 데 효과적입니다.

# %%
# content만 출력
print(response.content)
# Out:
# LangChain은 다양한 언어 모델과 데이터 소스를 통합하여 자연어 처리 애플리케이션을 구축할 수 있도록 돕는 프레임워크입니다.

# %% [markdown]
# ## 4. 메시지 객체로 호출
#
# 역할(role)을 구분하여 메시지를 전달할 수 있습니다.
# - `SystemMessage`: AI의 역할/페르소나 설정
# - `HumanMessage`: 사용자 입력

# %%
from langchain_core.messages import SystemMessage, HumanMessage

messages = [
    SystemMessage(content="당신은 친절한 파이썬 튜터입니다."),
    HumanMessage(content="""
                 리스트 컴프리헨션을 초보자에게 설명해줘
                 응답은 다음 형식으로 간략하게 
                 - 용도:
                 - 문법:
                 - 예시:
                 """)
]


response = llm.invoke(messages)
print(response.content)
# Out:
# - 용도: 리스트 컴프리헨션은 기존 리스트를 기반으로 새로운 리스트를 간결하게 생성하는 방법입니다. 반복문과 조건문을 사용하여 리스트를 쉽게 만들 수 있습니다.
#
# - 문법: `[표현식 for 항목 in iterable if 조건]`
#
# - 예시:
# ```python
# # 1부터 10까지의 제곱수를 리스트로 생성
# squares = [x**2 for x in range(1, 11)]
# print(squares)  # 출력: [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
#
# # 짝수만 필터링하여 리스트 생성
# even_squares = [x**2 for x in range(1, 11) if x % 2 == 0]
# print(even_squares)  # 출력: [4, 16, 36, 64, 100]
# ```

# %%
print(response.content)
# Out:
# 리스트 컴프리헨션(List Comprehension)은 파이썬에서 리스트를 간결하고 효율적으로 생성하는 방법입니다. 일반적으로 반복문을 사용하여 리스트를 만들 때보다 더 짧고 읽기 쉽게 코드를 작성할 수 있습니다.
#
# ### 기본 구조
#
# 리스트 컴프리헨션의 기본 구조는 다음과 같습니다:
#
# ```python
# [표현식 for 항목 in iterable if 조건]
# ```
#
# - **표현식**: 리스트의 각 요소를 어떻게 변형할지를 정의합니다.
# - **항목**: iterable(반복 가능한 객체)에서 가져오는 각 요소를 나타냅니다.
# - **iterable**: 리스트, 튜플, 문자열 등 반복 가능한 객체입니다.
# - **조건**: (선택 사항) 특정 조건을 만족하는 항목만 포함할 수 있습니다.
#
# ### 예제
#
# 1. **기본적인 리스트 생성**
#
#    1부터 5까지의 숫자로 이루어진 리스트를 만들고 싶다면, 다음과 같이 할 수 있습니다.
#
#    ```python
#    numbers = [x for x in range(1, 6)]
#    print(numbers)  # 출력: [1, 2, 3, 4, 5]
#    ```
#
# 2. **조건을 포함한 리스트 생성**
#
#    짝수만 포함하는 리스트를 만들고 싶다면, 조건을 추가할 수 있습니다.
#
#    ```python
#    even_numbers = [x for x in range(1, 11) if x % 2 == 0]
#    print(even_numbers)  # 출력: [2, 4, 6, 8, 10]
#    ```
#
# 3. **표현식을 변형하기**
#
#    각 숫자를 제곱한 값을 포함하는 리스트를 만들 수 있습니다.
#
#    ```python
#    squares = [x**2 for x in range(1, 6)]
#    print(squares)  # 출력: [1, 4, 9, 16, 25]
#    ```
#
# ### 요약
#
# 리스트 컴프리헨션은 반복문을 간결하게 표현할 수 있는 강력한 도구입니다. 이를 통해 코드의 가독성을 높이고, 더 적은 줄의 코드로 동일한 작업을 수행할 수 있습니다. 처음에는 익숙하지 않을 수 있지만, 연습을 통해 점점 더 편리하게 사용할 수 있게 될 것입니다!

# %% [markdown]
# - 마크다운으로 출력해서 보기

# %%
from IPython.display import Markdown, display
display(Markdown(response.content))
# Out:
# 리스트 컴프리헨션(List Comprehension)은 파이썬에서 리스트를 간결하고 효율적으로 생성하는 방법입니다. 일반적으로 반복문을 사용하여 리스트를 만들 때보다 더 짧고 읽기 쉽게 코드를 작성할 수 있습니다.
#
# ### 기본 구조
#
# 리스트 컴프리헨션의 기본 구조는 다음과 같습니다:
#
# ```python
# [표현식 for 항목 in iterable if 조건]
# ```
#
# - **표현식**: 리스트의 각 요소를 어떻게 변형할지를 정의합니다.
# - **항목**: iterable(반복 가능한 객체)에서 가져오는 각 요소를 나타냅니다.
# - **iterable**: 리스트, 튜플, 문자열 등 반복 가능한 객체입니다.
# - **조건**: (선택 사항) 특정 조건을 만족하는 경우에만 요소를 포함합니다.
#
# ### 예제
#
# 1. **기본 예제**: 0부터 9까지의 숫자를 제곱한 리스트 만들기
#
# ```python
# squares = [x**2 for x in range(10)]
# print(squares)  # [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# ```
#
# 2. **조건 추가**: 0부터 9까지의 숫자 중 짝수만 제곱한 리스트 만들기
#
# ```python
# even_squares = [x**2 for x in range(10) if x % 2 == 0]
# print(even_squares)  # [0, 4, 16, 36, 64]
# ```
#
# ### 장점
#
# - **간결함**: 코드가 짧고 명확해집니다.
# - **성능**: 일반적인 반복문보다 더 빠르게 실행될 수 있습니다.
#
# ### 요약
#
# 리스트 컴프리헨션은 파이썬에서 리스트를 생성하는 강력하고 유용한 도구입니다. 반복문을 사용하여 리스트를 만드는 대신, 한 줄의 코드로 더 간결하게 작성할 수 있습니다. 초보자도 쉽게 이해하고 사용할 수 있으니, 다양한 예제를 통해 연습해보는 것이 좋습니다!

# %% [markdown]
# ## 5. 스트리밍 호출 - stream()
#
# - 토큰이 생성되는 즉시 출력함.
# - llm 객체에 질문을 보내고, 응답을 한 번에 받지 않고 조각(chunk) 단위로 순차적으로 받음.
# - end=""를 쓰면 줄바꿈 없이 이어서 출력함.
# - flush=True는 출력 버퍼를 즉시 비우라는 의미임.

# %%
for chunk in llm.stream("최신 langchain 버전을 알여주고, 특장점을 알여줘 "):
    print(chunk.content, end="", flush=True)
# Out:
# 최신 LangChain 버전은 2023년 10월 기준으로 0.0.200입니다. LangChain은 다양한 언어 모델과의 통합을 지원하는 프레임워크로, 다음과 같은 특장점이 있습니다:
#
# 1. **모듈화**: LangChain은 다양한 구성 요소(예: 프롬프트, 체인, 메모리 등)를 모듈화하여 제공하므로, 사용자가 필요에 따라 쉽게 조합하고 확장할 수 있습니다.
#
# 2. **다양한 언어 모델 지원**: OpenAI, Hugging Face, Cohere 등 여러 언어 모델과의 통합을 지원하여 사용자가 원하는 모델을 선택할 수 있습니다.
#
# 3. **체인 구성**: 여러 작업을 순차적으로 연결하여 복잡한 작업을 수행할 수 있는 체인 기능을 제공합니다. 이를 통해 사용자는 복잡한 로직을 쉽게 구현할 수 있습니다.
#
# 4. **프롬프트 관리**: 프롬프트 템플릿을 쉽게 관리하고 사용할 수 있는 기능을 제공하여, 다양한 상황에 맞는 프롬프트를 손쉽게 생성할 수 있습니다.
#
# 5. **데이터 연결**: 외부 데이터 소스와의 연결을 지원하여, 실시간 데이터나 특정 데이터베이스에서 정보를 가져와 사용할 수 있습니다.
#
# 6. **커뮤니티와 생태계**: LangChain은 활발한 커뮤니티와 생태계를 가지고 있어, 다양한 예제와 자료를 통해 쉽게 학습하고 활용할 수 있습니다.
#
# 이러한 특장점 덕분에 LangChain은 다양한 자연어 처리(NLP) 애플리케이션을 개발하는 데 유용한 도구로 자리 잡고 있습니다.

# %% [markdown]
# ## 6. 응답 메타데이터 확인
#
# 토큰 사용량 등 메타정보를 확인할 수 있습니다.

# %%
response = llm.invoke("안녕")
# Out:
# content: 안녕하세요! 어떻게 도와드릴까요?
# usage: {'input_tokens': 9, 'output_tokens': 10, 'total_tokens': 19, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
